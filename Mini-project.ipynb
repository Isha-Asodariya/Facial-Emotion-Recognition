# %%
import matplotlib.pyplot as plt #For plotting
from keras.preprocessing.image import ImageDataGenerator #image data generator.
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import cv2
from PIL import Image

image = Image.open("C:\Users\kbaso\Dropbox\PC\Downloads\archive (1)\images\1\Happy.jpg")
# Out:
#   Cell In[1], line 9
#     image = Image.open("C:\Users\kbaso\Dropbox\PC\Downloads\archive (1)\images\1\Happy.jpg")
#                                                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import matplotlib.pyplot as plt #For plotting
from keras.preprocessing.image import ImageDataGenerator #image data generator.
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import cv2
from PIL import Image

image = Image.open('Happy.jpg')
plt.imshow(image)
plt.show()

# %%
import matplotlib.pyplot as plt #For plotting
from keras.preprocessing.image import ImageDataGenerator #image data generator.
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import cv2
from PIL import Image

image = Image.open('Happy.jpg')
plt.imshow(image)
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('Happy.jpg')
gray_image = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

fig, ax = plt.subplots(1, 2, figsize=(16, 8))
fig.tight_layout()

ax[0].imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
ax[0].set_title("Original")

# %%
import cv2
import matplotlib.pyplot as plt

pic1 = plt.imread('Happy.jpg')
plt.imshow(pic1)

# %%
import cv2
import matplotlib.pyplot as plt

pic1 = plt.imread('Happy.jpg')
plt.imshow(pic1)

# %%
from PIL import Image
import matplotlib.pyplot as plt


image_path = 'C://Users//kbaso//OneDrive//Desktop//Mini Project//Happy.jpg'

img = Image.open(image_path)
plt.imshow(img)

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

pic1 = plt.imread('Happy.jpg')
plt.imshow(pic1)

# %%
import cv2
from deepface import DeepFace

# Load the pre-trained emotion detection model
model = DeepFace.build_model("Emotion")

# Define emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Load face cascade classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start capturing video
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI (Region of Interest)
        face_roi = gray_frame[y:y + h, x:x + w]

        # Resize the face ROI to match the input shape of the model
        resized_face = cv2.resize(face_roi, (48, 48), interpolation=cv2.INTER_AREA)

        # Normalize the resized face image
        normalized_face = resized_face / 255.0

        # Reshape the image to match the input shape of the model
        reshaped_face = normalized_face.reshape(1, 48, 48, 1)

        # Predict emotions using the pre-trained model
        preds = model.predict(reshaped_face)[0]
        emotion_idx = preds.argmax()
        emotion = emotion_labels[emotion_idx]

        # Draw rectangle around face and label with predicted emotion
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
        cv2.putText(frame, emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the resulting frame
    cv2.imshow('Real-time Emotion Detection', frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
# !pip install opencv-python

# %%
# !pip install deepface

# %%
# !pip install deepface

# %%
import cv2
import matplotlib.pyplot as plt

img = plt.imread('Happy.jpg')
plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt

img = plt.imread('Happy.jpg')
plt.imshow(img)

# %%
import cv2
from deepface import DeepFace

# Load the pre-trained emotion detection model
model = DeepFace.build_model("Emotion")

# Define emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Load face cascade classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start capturing video
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI (Region of Interest)
        face_roi = gray_frame[y:y + h, x:x + w]

        # Resize the face ROI to match the input shape of the model
        resized_face = cv2.resize(face_roi, (48, 48), interpolation=cv2.INTER_AREA)

        # Normalize the resized face image
        normalized_face = resized_face / 255.0

        # Reshape the image to match the input shape of the model
        reshaped_face = normalized_face.reshape(1, 48, 48, 1)

        # Predict emotions using the pre-trained model
        preds = model.predict(reshaped_face)[0]
        emotion_idx = preds.argmax()
        emotion = emotion_labels[emotion_idx]

        # Draw rectangle around face and label with predicted emotion
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
        cv2.putText(frame, emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the resulting frame
    cv2.imshow('Real-time Emotion Detection', frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
from deepface import DeepFace

# Load the pre-trained emotion detection model
model = DeepFace.build_model("Emotion")

# Define emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Load face cascade classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start capturing video
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI (Region of Interest)
        face_roi = gray_frame[y:y + h, x:x + w]

        # Resize the face ROI to match the input shape of the model
        resized_face = cv2.resize(face_roi, (48, 48), interpolation=cv2.INTER_AREA)

        # Normalize the resized face image
        normalized_face = resized_face / 255.0

        # Reshape the image to match the input shape of the model
        reshaped_face = normalized_face.reshape(1, 48, 48, 1)

        # Predict emotions using the pre-trained model
        preds = model.predict(reshaped_face)[0]
        emotion_idx = preds.argmax()
        emotion = emotion_labels[emotion_idx]

        # Draw rectangle around face and label with predicted emotion
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
        cv2.putText(frame, emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the resulting frame
    cv2.imshow('Real-time Emotion Detection', frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
from deepface import DeepFace

# Load the pre-trained emotion detection model
model = DeepFace.build_model("Emotion")

# Define emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Load face cascade classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start capturing video
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI (Region of Interest)
        face_roi = gray_frame[y:y + h, x:x + w]

        # Resize the face ROI to match the input shape of the model
        resized_face = cv2.resize(face_roi, (48, 48), interpolation=cv2.INTER_AREA)

        # Normalize the resized face image
        normalized_face = resized_face / 255.0

        # Reshape the image to match the input shape of the model
        reshaped_face = normalized_face.reshape(1, 48, 48, 1)

        # Predict emotions using the pre-trained model
        preds = model.predict(reshaped_face)[0]
        emotion_idx = preds.argmax()
        emotion = emotion_labels[emotion_idx]

        # Draw rectangle around face and label with predicted emotion
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
        cv2.putText(frame, emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the resulting frame
    cv2.imshow('Real-time Emotion Detection', frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
from deepface import Deepface

# %%
# !pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\kbaso\anaconda3\lib\site-packages (0.0.85)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (2.1.4)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (5.1.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (10.2.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (4.9.0.80)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (2.15.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (3.1.1)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (2.2.5)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (0.0.14)
# Requirement already satisfied: fire>=0.4.0 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (0.5.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\kbaso\anaconda3\lib\site-packages (from deepface) (21.2.0)
# Requirement already satisfied: six in c:\users\kbaso\appdata\roaming\python\python311\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\kbaso\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\kbaso\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\kbaso\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\kbaso\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\kbaso\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\kbaso\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\kbaso\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: requests[socks] in c:\users\kbaso\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (2.31.0)
# Requirement already satisfied: packaging in c:\users\kbaso\appdata\roaming\python\python311\site-packages (from gunicorn>=20.1.0->deepface) (23.1)
# Requirement already satisfied: absl-py in c:\users\kbaso\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (2.1.0)
# Requirement already satisfied: rich in c:\users\kbaso\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (13.3.5)
# Requirement already satisfied: namex in c:\users\kbaso\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.0.7)
# Requirement already satisfied: h5py in c:\users\kbaso\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (3.9.0)
# Requirement already satisfied: optree in c:\users\kbaso\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.11.0)
# Requirement already satisfied: ml-dtypes in c:\users\kbaso\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kbaso\appdata\roaming\python\python311\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kbaso\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kbaso\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (68.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.15.0)
# Collecting keras>=2.2.0 (from deepface)
#   Obtaining dependency information for keras>=2.2.0 from https://files.pythonhosted.org/packages/fc/a7/0d4490de967a67f68a538cc9cdb259bff971c4b5787f7765dc7c8f118f71/keras-2.15.0-py3-none-any.whl.metadata
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: colorama in c:\users\kbaso\appdata\roaming\python\python311\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kbaso\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kbaso\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kbaso\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kbaso\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kbaso\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kbaso\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\kbaso\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kbaso\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kbaso\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\kbaso\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kbaso\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kbaso\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kbaso\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kbaso\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kbaso\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\kbaso\anaconda3\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kbaso\appdata\roaming\python\python311\site-packages (from rich->keras>=2.2.0->deepface) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kbaso\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.0)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.1.1
#     Uninstalling keras-3.1.1:
#       Successfully uninstalled keras-3.1.1
# Successfully installed keras-2.15.0

# %%
from deepface import Deepface
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from deepface import Deepface
#
# ImportError: cannot import name 'Deepface' from 'deepface' (C:\Users\kbaso\anaconda3\Lib\site-packages\deepface\__init__.py)

# %%
from deepface import DeepFace

# %%
predictions=DeepFace.analyze(img)

# %%
import cv2
from deepface import DeepFace
import matplotlib.pyplot as plt

img = plt.imread('Happy.jpg')
plt.imshow(img)

# %%
predictions=DeepFace.analyze(img)
